# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Traffic-Violation-Detection/
# Out:
# /content/gdrive/MyDrive/Traffic-Violation-Detection

# %%
# !pip install imageio==2.31.6
# !pip install scikit-image==0.22.0
# !pip install imgaug==0.4.0
# !pip install matplotlib==3.8.1
# !pip install numpy==1.26.1
# !pip install opencv_python==4.8.1.78
# !pip install opencv_python_headless==4.8.1.78
# !pip install Pillow==10.1.0
# !pip install pytesseract==0.3.10
# !pip install ultralytics==8.0.203
# !pip install tesseract
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 29.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 10.1.0
#     Uninstalling Pillow-10.1.0:
#       Successfully uninstalled Pillow-10.1.0
# ...
#   Using cached Pillow-10.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 10.0.1
#     Uninstalling Pillow-10.0.1:
#       Successfully uninstalled Pillow-10.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 MB 16.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
#!python xml2txt.py --annotations_path ./Car-License-Plate/annotations --labels_path ./Car-License-Plate/labels --classes licence=0

# %%
#!python dataset_preparation.py --data_path Car-License-Plate --train_path dataset/train --valid_path dataset/valid --split_ratio 0.8

# %%
#!python data_augmentation.py --train_path dataset/train --num_augmentations 5
# Out:
# Augmenting Images: 100% 346/346 [20:59<00:00,  3.64s/it]

# %%
# !python train.py --data_config data.yaml --epochs 100 --model_name yolov8n.pt --export_format onnx --onnx_path model.onnx --pt_path model.pt
# Out:
# New https://pypi.org/project/ultralytics/8.0.218 available 😃 Update with 'pip install -U ultralytics'
# ...

# %%
# !python inference.py
# Out:
# 0: 448x640 2 licenses, 177.3ms
# Speed: 5.0ms preprocess, 177.3ms inference, 9.5ms postprocess per image at shape (1, 3, 448, 640)
# license_plate: {0025
#
# License: {0025
# license_plate:
# License:
